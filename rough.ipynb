# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 
import shutil
import json
import re
import os

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable
import torch.utils.data as data_utils
from torch.nn.modules import MSELoss, L1Loss

import sklearn.preprocessing
from sklearn.preprocessing import MultiLabelBinarizer
import glob
import csv
import cv2
import random
from PIL import Image
from itertools import product

# %%
path1 = './Movie_Poster_Metadata/groundtruth'
temp_path = './Movie_Poster_Metadata/temp_groundtruth'
path2 = './Movie_Poster_Metadata/updated_groundtruth'

# %%
def reconstruct_metadata():
    dir_list = os.listdir(path1)

    if not os.path.exists(temp_path):
        os.makedirs(temp_path)

    if not os.path.exists(path2):
        os.makedirs(path2)
    else: 
        print('directories already exists. not cleaning metadata')
        return None

    #adding comma between json objects from path1
    for file_name in dir_list:
        with open(path1+ '/' + file_name, 'r', encoding='utf-16-le') as file1:
            temp_file = open(temp_path + '/' + file_name, 'w', encoding='utf-8')
            for line in file1.readlines():
                #adding comma at the end of each poster metdata for ease of seperation
                line = line.replace('}\n','},\n') 
                #read all lines starting with """_id"
                y = re.findall('^ \'_id\'', line)
                if not y:
                    temp_file.write(line)
        file1.close()
        temp_file.close()

    dir_list = os.listdir(temp_path)

    #create final json array from temp_file's json objects
    for file_name in dir_list:
        with open(temp_path + '/' + file_name, 'r',  encoding = 'utf-8') as temp_file:
            file2 = open(path2 + '/' + file_name, 'w', encoding = 'utf-8')
            lines = temp_file.readlines()
            lines = lines[1:-1] #removing movie id from each json object
            file2.write('[{')
            file2.writelines(lines)
            file2.write('}]')
        temp_file.close()
        file2.close()
    
    shutil.rmtree(temp_path) #delete temporary file

    return None

# %%
reconstruct_metadata()
# Out:
# directories already exists. not cleaning metadata

# %%
folder_directory = './Movie_Poster_Dataset'
folders = os.listdir(folder_directory)

# %%
# path3 = './Movie_Poster_Dataset/'
# plot_counter = 0

# for dirname in os.listdir(path3):
#     for filename in os.listdir(path3 + '/' + dirname):
#         name, ext = os.path.splitext(filename)
#         if (ext == '.jpg'):
#             image = Image.open(os.path.join(path3 + '/' + dirname, filename))
#             width, height = image.size
#             chopsize = 300
#             for x0 in range(0, width, chopsize):
#                 for y0 in range(0, height, chopsize):
#                     if plot_counter < 10 and (y0 + chopsize <= height) and (x0 + chopsize <= width):
#                         box = (x0, y0, x0+chopsize, y0+chopsize)
#                         cropped_image = image.crop(box)

#                         plt.subplot(2,5, plot_counter +1)
#                         plt.imshow(cropped_image)
#                         plt.axis('off')

#                         print('%s.x%03d.y%03d.jpg' % (filename.replace('.jpg',''), x0, y0))

#                         plot_counter += 1

# %%
# '''
# salt and perpper noise
# '''

# path3 = './Movie_Poster_Dataset/'
# plot_counter = 0

# for dirname in os.listdir(path3):
#     for filename in os.listdir(path3 + '/' + dirname):
#         name, ext = os.path.splitext(filename)
#         if (ext == '.jpg'):
#             if plot_counter<10:
#                 image = Image.open(os.path.join(path3 + '/' + dirname, filename))

#                 img_array = np.array(image)

#                 noise_intensity = random.uniform(0.2, 0.5)
                
#                 salt_and_pepper = np.random.choice([0,1,2], 
#                                                    size = img_array.shape, 
#                                                    p=[1 - noise_intensity,
#                                                         noise_intensity/2.0,
#                                                         noise_intensity/2.0])
                
#                 noisy_image_array = img_array.copy()
#                 noisy_image_array[salt_and_pepper == 1] = 255 #set salt pixels to white
#                 noisy_image_array[salt_and_pepper == 2] = 0 #set pepper pixels to black
                


#                 # noise = np.random.normal(loc=0, scale =40, size = img_array.shape)
#                 # noisy_image_array = np.clip(img_array + noise, 0, 255).astype(np.uint8)

#                 noisy_image = Image.fromarray(noisy_image_array)

                
#                 print('%s_noisy.jpg' %name)
#                 plot_counter+=1

#                 plt.figure(figsize= (8,4))
#                 plt.subplot(1,2,1)
#                 plt.imshow(image)
#                 plt.title('original image')

#                 plt.subplot(1,2,2)
#                 plt.imshow(noisy_image)
#                 plt.title('noisy image')

#                 plt.show()

# %%
# Create a new folder for augmented images
#add salt and pepper noisy image
augmented_folder = './Movie_Poster_Dataset_Augmented/'
os.makedirs(augmented_folder, exist_ok=True)

path3 = './Movie_Poster_Dataset/'

for dirname in os.listdir(path3):
    for filename in os.listdir(os.path.join(path3, dirname)):
        name, ext = os.path.splitext(filename)
        if ext == '.jpg':
            image = Image.open(os.path.join(path3, dirname, filename))
            img_array = np.array(image)

            noise_intensity = random.uniform(0.05, 0.2)

            salt_and_pepper = np.random.choice([0, 1, 2], 
                                               size=img_array.shape, 
                                               p=[1 - noise_intensity,
                                                  noise_intensity/2.0,
                                                  noise_intensity/2.0])

            noisy_image_array = img_array.copy()
            noisy_image_array[salt_and_pepper == 1] = 255  # Set salt pixels to white
            noisy_image_array[salt_and_pepper == 2] = 0    # Set pepper pixels to black

            # Save the augmented image
            new_filename = os.path.join(augmented_folder, f'{name}_salty.jpg')
            Image.fromarray(noisy_image_array).save(new_filename)

# %%
#drop pixels and add them to folder
path3 = './Movie_Poster_Dataset/'
augmented_folder = './Movie_Poster_Dataset_Augmented/'
os.makedirs(augmented_folder, exist_ok=True)

for dirname in os.listdir(path3):
    for filename in os.listdir(path3 + '/' + dirname):
        name, ext = os.path.splitext(filename)
        if ext == '.jpg':
            image = Image.open(os.path.join(path3 + '/' + dirname, filename))

            img_array = np.array(image)
            drop_percentage = random.uniform(0.2, 0.5)
            num_blocks = random.randint(200, 300)

            for _ in range(num_blocks):
                block_size_x = random.randint(5, 20)
                block_size_y = random.randint(5, 20)
                height, width, channels = img_array.shape
                start_x = random.randint(0, width - block_size_x)
                start_y = random.randint(0, height - block_size_y)

                # Randomly choose channels to set to 0
                channels_to_drop = random.sample(range(channels), random.randint(1, channels-1))

                img_array[start_y: start_y + block_size_y, start_x: start_x + block_size_x, channels_to_drop] = 0

            dropped_image = Image.fromarray(img_array.astype(np.uint8))

            #save augmented image
            new_filename = os.path.join(augmented_folder, f'{name}_dropped.jpg')
            dropped_image.save(new_filename)

# %%
# path3 = './Movie_Poster_Dataset/'
# plot_counter = 0

# for dirname in os.listdir(path3):
#     for filename in os.listdir(path3 + '/' + dirname):
#         name, ext = os.path.splitext(filename)
#         if ext == '.jpg':
#             if plot_counter < 10:
#                 image = Image.open(os.path.join(path3 + '/' + dirname, filename))

#                 img_array = np.array(image)
#                 drop_percentage = random.uniform(0.2, 0.5)
#                 num_blocks = random.randint(200, 300)

#                 for _ in range(num_blocks):
#                     block_size_x = random.randint(5, 20)
#                     block_size_y = random.randint(5, 20)
#                     height, width, channels = img_array.shape
#                     start_x = random.randint(0, width - block_size_x)
#                     start_y = random.randint(0, height - block_size_y)

#                     # Randomly choose channels to set to 0
#                     channels_to_drop = random.sample(range(channels), random.randint(1, channels-1))

#                     img_array[start_y: start_y + block_size_y, start_x: start_x + block_size_x, channels_to_drop] = 0

#                 dropped_image = Image.fromarray(img_array.astype(np.uint8))

#                 print('%s_dropped.jpg' % name)
#                 plot_counter += 1

#                 plt.figure(figsize=(8, 4))
#                 plt.subplot(1, 2, 1)
#                 plt.imshow(image)
#                 plt.title('Original Image')

#                 plt.subplot(1, 2, 2)
#                 plt.imshow(dropped_image)
#                 plt.title('Dropped Image')

#                 plt.show()

# %%
# '''
# adding noise
# '''


# path3 = './Movie_Poster_Dataset/'
# plot_counter = 0

# for dirname in os.listdir(path3):
#     for filename in os.listdir(path3 + '/' + dirname):
#         name, ext = os.path.splitext(filename)
#         if (ext == '.jpg'):
#             if plot_counter<10:
#                 image = Image.open(os.path.join(path3 + '/' + dirname, filename))

#                 img_array = np.array(image)

#                 drop_percentage = random.uniform(0.2,0.5)
#                 # Choose the channels to drop pixels from (1 to 3 channels)
#                 channels_to_drop = random.sample(range(img_array.shape[2]), random.randint(1, img_array.shape[2]))

#                 for channel in channels_to_drop:
#                     drop_mask = np.random.choice([0,1], size = img_array.shape[:2], p= [drop_percentage,1 - drop_percentage])
#                     img_array[:, :, channel] = img_array[:, :, channel] * drop_mask

                
#                 dropped_image = Image.fromarray(img_array)

                
#                 print('%s_dropped.jpg' %name)
#                 plot_counter+=1

#                 plt.figure(figsize= (8,4))
#                 plt.subplot(1,2,1)
#                 plt.imshow(image)
#                 plt.title('original image')

#                 plt.subplot(1,2,2)
#                 plt.imshow(dropped_image)
#                 plt.title('dropped image')

#                 plt.show()

# %%
# path3 = './Movie_Poster_Dataset/'
# plot_counter = 0

# for dirname in os.listdir(path3):
#     for filename in os.listdir(path3 + '/' + dirname):
#         name, ext = os.path.splitext(filename)
#         if (ext == '.jpg'):
#             if plot_counter<10:
#                 image = Image.open(os.path.join(path3 + '/' + dirname, filename))

#                 img_array = np.array(image)

#                 # noise_intensity = random.uniform(60, 200)
#                 noise_intensity = 200
#                 for _ in range(200):
#                     x, y = random.randint(0, img_array.shape[0]-1), random.randint(0, img_array.shape[1]-1)
#                     img_array[x,y,:] = np.clip(img_array[x,y,:] + np.random.normal(loc=0, scale=noise_intensity, size=3), 0, 255)

#                 # noise = np.random.normal(loc=0, scale =40, size = img_array.shape)
#                 # noisy_image = np.clip(img_array + noise, 0, 255).astype(np.uint8)

#                 noisy_image = Image.fromarray(img_array)

                
#                 print('%s_noisy.jpg' %name)
#                 plot_counter+=1

#                 plt.figure(figsize= (8,4))
#                 plt.subplot(1,2,1)
#                 plt.imshow(image)
#                 plt.title('original image')

#                 plt.subplot(1,2,2)
#                 plt.imshow(noisy_image)
#                 plt.title('noisy image')

#                 plt.show()

# %%
#add distorted images to folder

augmented_folder = './Movie_Poster_Dataset_Augmented/'
os.makedirs(augmented_folder, exist_ok=True)
path3 = './Movie_Poster_Dataset/'

def apply_color_distortion(img_array):
    # Apply color distortion (changes in hue)
    hue_shift = random.randint(-50, 50)
    img_array = (img_array + hue_shift) % 256

    return img_array

for dirname in os.listdir(path3):
    for filename in os.listdir(path3 + '/' + dirname):
        name, ext = os.path.splitext(filename)
        if (ext == '.jpg'):
            image = Image.open(os.path.join(path3 + '/' + dirname, filename))

            img_array = np.array(image)

            #apply color distortion
            img_array = apply_color_distortion(img_array)

            # noise = np.random.normal(loc=0, scale =40, size = img_array.shape)
            # noisy_image_array = np.clip(img_array + noise, 0, 255).astype(np.uint8)

            distorted_image = Image.fromarray(img_array.astype(np.uint8))

            #save augmented image
            new_filename = os.path.join(augmented_folder, f'{name}_distorted.jpg')
            distorted_image.save(new_filename)

# %%
# # Iterate through files in the folder
# for filename in os.listdir(augmented_folder):
#     # Check if the filename ends with "_distorted"
#     if filename.endswith("_distorted.jpg"):
#         # Construct the full file path
#         file_path = os.path.join(augmented_folder, filename)
        
#         try:
#             # Attempt to remove the file
#             os.remove(file_path)
#             print(f"Deleted: {file_path}")
#         except Exception as e:
#             print(f"Error deleting {file_path}: {e}")

# %%
# ''''
# changine some colors and hues
# '''

# def apply_color_distortion(img_array):
#     # Apply color distortion (changes in hue)
#     hue_shift = random.randint(-50, 50)
#     img_array = (img_array + hue_shift) % 256

#     return img_array

# path3 = './Movie_Poster_Dataset/'
# plot_counter = 0

# for dirname in os.listdir(path3):
#     for filename in os.listdir(path3 + '/' + dirname):
#         name, ext = os.path.splitext(filename)
#         if (ext == '.jpg'):
#             if plot_counter<10:
#                 image = Image.open(os.path.join(path3 + '/' + dirname, filename))

#                 img_array = np.array(image)

#                 #apply color distortion
#                 img_array = apply_color_distortion(img_array)

#                 # noise = np.random.normal(loc=0, scale =40, size = img_array.shape)
#                 # noisy_image_array = np.clip(img_array + noise, 0, 255).astype(np.uint8)

#                 distorted_image = Image.fromarray(img_array.astype(np.uint8))

                
#                 print('%s_distorted.jpg' %name)
#                 plot_counter+=1

#                 plt.figure(figsize= (8,4))
#                 plt.subplot(1,2,1)
#                 plt.imshow(image)
#                 plt.title('original image')

#                 plt.subplot(1,2,2)
#                 plt.imshow(distorted_image)
#                 plt.title('distorted image')

#                 plt.show()

# %%
# ''''
# blacking out parts
# '''

# path3 = './Movie_Poster_Dataset/'
# plot_counter = 0

# for dirname in os.listdir(path3):
#     for filename in os.listdir(path3 + '/' + dirname):
#         name, ext = os.path.splitext(filename)
#         if (ext == '.jpg'):
#             if plot_counter<10:
#                 image = Image.open(os.path.join(path3 + '/' + dirname, filename))

#                 img_array = np.array(image)
#                 num_erasings = random.randint(2,5)

#                 for _ in range(num_erasings):
#                     erase_size = random.randint(50,80)
#                     height, width, _ = img_array.shape
#                     start_x = random.randint(0, width - erase_size)
#                     start_y = random.randint(0, height - erase_size)
#                     img_array[start_y: start_y+erase_size, start_x:start_x+erase_size, :] = 0


#                 # erase_size_x = 100
#                 # erase_size_y = 150
#                 # height, width, _ = img_array.shape
#                 # start_x = random.randint(0, width - erase_size_x)
#                 # start_y = random.randint(0, height - erase_size_y)

#                 # img_array[start_y: start_y+erase_size_y, start_x:start_x+erase_size_x, :] = 0
#                 erased_image = Image.fromarray(img_array.astype(np.uint8))

#                 # noise = np.random.normal(loc=0, scale =40, size = img_array.shape)
#                 # noisy_image_array = np.clip(img_array + noise, 0, 255).astype(np.uint8)

#                 # noisy_image = Image.fromarray(noisy_image_array)

                
#                 print('%s_noisy.jpg' %name)
#                 plot_counter+=1

#                 plt.figure(figsize= (8,4))
#                 plt.subplot(1,2,1)
#                 plt.imshow(image)
#                 plt.title('original image')

#                 plt.subplot(1,2,2)
#                 plt.imshow(erased_image)
#                 plt.title('erased image')

#                 plt.show()

# %%
#add rotation to images and add them to folder
path3 = './Movie_Poster_Dataset/'
augmented_folder = './Movie_Poster_Dataset_Augmented/'
os.makedirs(augmented_folder, exist_ok=True)

for dirname in os.listdir(path3):
    for filename in os.listdir(path3 + '/' + dirname):
        name, ext = os.path.splitext(filename)
        if (ext == '.jpg'):
                image = Image.open(os.path.join(path3 + '/' + dirname, filename))

                rotation_angle = random.uniform(-180,180)
                rotated_image = image.rotate(rotation_angle)

                # print('%s_rotated.jpg' %name)

                #save augmented image
                new_filename = os.path.join(augmented_folder, f'{name}_rotated.jpg')
                rotated_image.save(new_filename)

# %%
# path3 = './Movie_Poster_Dataset/'
# plot_counter = 0

# for dirname in os.listdir(path3):
#     for filename in os.listdir(path3 + '/' + dirname):
#         name, ext = os.path.splitext(filename)
#         if (ext == '.jpg'):
#             if plot_counter<10:
#                 image = Image.open(os.path.join(path3 + '/' + dirname, filename))

#                 rotation_angle = random.uniform(-180,180)
#                 rotated_image = image.rotate(rotation_angle)

#                 print('%s_rotated.jpg' %name)
#                 plot_counter+=1

                # plt.figure(figsize= (8,4))
                # plt.subplot(1,2,1)
                # plt.imshow(image)
                # plt.title('original image')

                # plt.subplot(1,2,2)
                # plt.imshow(rotated_image)
                # plt.title('rotated image')

                # plt.show()
